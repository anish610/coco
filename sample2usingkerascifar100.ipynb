# %%
import keras
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
batch_size = 1000
num_classes = 100
num_samples=10
epochs = 20

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

plt.imshow(x_train[0])
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('x_train shape:', y_train.shape)
print(y_train.shape[0], 'train samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# x_train shape: (50000, 1)
# 50000 train samples

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               51300
# _________________________________________________________________
# activation_6 (Activation)    (None, 100)               0
# =================================================================
# Total params: 1,297,028
# Trainable params: 1,297,028
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=no
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\theano\tensor\nnet\conv.py:98: UserWarning: theano.tensor.nnet.conv.conv2d is deprecated. Use theano.tensor.nnet.conv2d instead.
#   warnings.warn("theano.tensor.nnet.conv.conv2d is deprecated."
# ERROR (theano.gof.opt): Optimization failure due to: local_abstractconv_check
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, 3, 32, 32), kshp=(32, 3, 3, 3), filter_dilation=(1, 1), num_groups=1, unshared=False}(InplaceDimShuffle{0,3,1,2}.0, InplaceDimShuffle{3,2,0,1}.0)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py", line 2019, in process_node
#     replacements = lopt.transform(node)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\theano\tensor\nnet\opt.py", line 500, in local_abstractconv_check
#     node.op.__class__.__name__)
# AssertionError: AbstractConv2d Theano optimization failed: there is no implementation available supporting the requested options. Did you exclude both "conv_dnn" and "conv_gemm" from the optimizer? If on GPU, is cuDNN available and does the GPU support it? If on CPU, do you have a BLAS library installed Theano can link against? On the CPU we do not support float16.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-91-8124a45895b2> in <module>()
#       3                     epochs=epochs,
#       4                     verbose=1,
# ----> 5                     validation_data=(x_test, y_test))
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     961                               initial_epoch=initial_epoch,
#     962                               steps_per_epoch=steps_per_epoch,
# --> 963                               validation_steps=validation_steps)
#     964
#     965     def evaluate(self, x=None, y=None,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1680         else:
#    1681             ins = x + y + sample_weights
# -> 1682         self._make_train_function()
#    1683         f = self.train_function
#    1684
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in _make_train_function(self)
#     995                                                  updates=updates,
#     996                                                  name='train_function',
# --> 997                                                  **self._function_kwargs)
#     998
#     999     def _make_test_function(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\theano_backend.py in function(inputs, outputs, updates, **kwargs)
#    1234                 msg = 'Invalid argument "%s" passed to K.function with Theano backend' % key
#    1235                 raise ValueError(msg)
# -> 1236     return Function(inputs, outputs, updates=updates, **kwargs)
#    1237
#    1238
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\theano_backend.py in __init__(self, inputs, outputs, updates, name, **kwargs)
#    1220                                         on_unused_input='ignore',
#    1221                                         name=name,
# -> 1222                                         **kwargs)
#    1223         self.name = name
#    1224
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\compile\function.py in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     315                    on_unused_input=on_unused_input,
#     316                    profile=profile,
# --> 317                    output_keys=output_keys)
#     318     return fn
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\compile\pfunc.py in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     484                          accept_inplace=accept_inplace, name=name,
#     485                          profile=profile, on_unused_input=on_unused_input,
# --> 486                          output_keys=output_keys)
#     487
#     488
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\compile\function_module.py in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1837                   on_unused_input=on_unused_input,
#    1838                   output_keys=output_keys,
# -> 1839                   name=name)
#    1840         with theano.change_flags(compute_test_value="off"):
#    1841             fn = m.create(defaults)
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\compile\function_module.py in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys, name)
#    1517                         optimizer, inputs, outputs)
#    1518                 else:
# -> 1519                     optimizer_profile = optimizer(fgraph)
#    1520
#    1521                 end_optimizer = time.time()
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in __call__(self, fgraph)
#      97
#      98         """
# ---> 99         return self.optimize(fgraph)
#     100
#     101     def add_requirements(self, fgraph):
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in optimize(self, fgraph, *args, **kwargs)
#      86             orig = theano.tensor.basic.constant.enable
#      87             theano.tensor.basic.constant.enable = False
# ---> 88             ret = self.apply(fgraph, *args, **kwargs)
#      89         finally:
#      90             theano.tensor.basic.constant.enable = orig
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in apply(self, fgraph)
#     240                     nb_nodes_before = len(fgraph.apply_nodes)
#     241                     t0 = time.time()
# --> 242                     sub_prof = optimizer.optimize(fgraph)
#     243                     l.append(float(time.time() - t0))
#     244                     sub_profs.append(sub_prof)
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in optimize(self, fgraph, *args, **kwargs)
#      86             orig = theano.tensor.basic.constant.enable
#      87             theano.tensor.basic.constant.enable = False
# ---> 88             ret = self.apply(fgraph, *args, **kwargs)
#      89         finally:
#      90             theano.tensor.basic.constant.enable = orig
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in apply(self, fgraph, start_from)
#    2126                     continue
#    2127                 current_node = node
# -> 2128                 nb += self.process_node(fgraph, node)
#    2129             loop_t = time.time() - t0
#    2130         finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in process_node(self, fgraph, node, lopt)
#    2022                 self.failure_callback(e, self,
#    2023                                       [(x, None) for x in node.outputs],
# -> 2024                                       lopt, node)
#    2025                 return False
#    2026             else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in warn_inplace(exc, nav, repl_pairs, local_opt, node)
#    1916         if isinstance(exc, InconsistencyError):
#    1917             return
# -> 1918         return NavigatorOptimizer.warn(exc, nav, repl_pairs, local_opt, node)
#    1919
#    1920     @staticmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in warn(exc, nav, repl_pairs, local_opt, node)
#    1902             # We always crash on AssertionError because something may be
#    1903             # seriously wrong if such an exception is raised.
# -> 1904             raise exc
#    1905
#    1906     @staticmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in process_node(self, fgraph, node, lopt)
#    2017         lopt = lopt or self.local_opt
#    2018         try:
# -> 2019             replacements = lopt.transform(node)
#    2020         except Exception as e:
#    2021             if self.failure_callback is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\tensor\nnet\opt.py in local_abstractconv_check(node)
#     498             'do you have a BLAS library installed Theano can link against? '
#     499             'On the CPU we do not support float16.' %
# --> 500             node.op.__class__.__name__)
#     501
#     502 optdb.register('AbstractConvCheck',
#
# AssertionError: AbstractConv2d Theano optimization failed: there is no implementation available supporting the requested options. Did you exclude both "conv_dnn" and "conv_gemm" from the optimizer? If on GPU, is cuDNN available and does the GPU support it? If on CPU, do you have a BLAS library installed Theano can link against? On the CPU we do not support float16.

# %%
score= model.evaluate(x_test ,y_test, verbose=0)
print('test loss',score[0])
print('test accuracy',score[1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\theano\tensor\nnet\conv.py:98: UserWarning: theano.tensor.nnet.conv.conv2d is deprecated. Use theano.tensor.nnet.conv2d instead.
#   warnings.warn("theano.tensor.nnet.conv.conv2d is deprecated."
# ERROR (theano.gof.opt): Optimization failure due to: local_abstractconv_check
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, 3, 32, 32), kshp=(32, 3, 3, 3), filter_dilation=(1, 1), num_groups=1, unshared=False}(InplaceDimShuffle{0,3,1,2}.0, InplaceDimShuffle{3,2,0,1}.0)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py", line 2019, in process_node
#     replacements = lopt.transform(node)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\theano\tensor\nnet\opt.py", line 500, in local_abstractconv_check
#     node.op.__class__.__name__)
# AssertionError: AbstractConv2d Theano optimization failed: there is no implementation available supporting the requested options. Did you exclude both "conv_dnn" and "conv_gemm" from the optimizer? If on GPU, is cuDNN available and does the GPU support it? If on CPU, do you have a BLAS library installed Theano can link against? On the CPU we do not support float16.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-92-bb0f1907cbdb> in <module>()
# ----> 1 score= model.evaluate(x_test ,y_test, verbose=0)
#       2 print('test loss',score[0])
#       3 print('test accuracy',score[1])
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\models.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps)
#    1002                                    verbose=verbose,
#    1003                                    sample_weight=sample_weight,
# -> 1004                                    steps=steps)
#    1005
#    1006     def predict(self, x, batch_size=None, verbose=0, steps=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps)
#    1772         else:
#    1773             ins = x + y + sample_weights
# -> 1774         self._make_test_function()
#    1775         f = self.test_function
#    1776         return self._test_loop(f, ins,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in _make_test_function(self)
#    1010                                             updates=self.state_updates + self.metrics_updates,
#    1011                                             name='test_function',
# -> 1012                                             **self._function_kwargs)
#    1013
#    1014     def _make_predict_function(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\theano_backend.py in function(inputs, outputs, updates, **kwargs)
#    1234                 msg = 'Invalid argument "%s" passed to K.function with Theano backend' % key
#    1235                 raise ValueError(msg)
# -> 1236     return Function(inputs, outputs, updates=updates, **kwargs)
#    1237
#    1238
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\theano_backend.py in __init__(self, inputs, outputs, updates, name, **kwargs)
#    1220                                         on_unused_input='ignore',
#    1221                                         name=name,
# -> 1222                                         **kwargs)
#    1223         self.name = name
#    1224
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\compile\function.py in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     315                    on_unused_input=on_unused_input,
#     316                    profile=profile,
# --> 317                    output_keys=output_keys)
#     318     return fn
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\compile\pfunc.py in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     484                          accept_inplace=accept_inplace, name=name,
#     485                          profile=profile, on_unused_input=on_unused_input,
# --> 486                          output_keys=output_keys)
#     487
#     488
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\compile\function_module.py in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1837                   on_unused_input=on_unused_input,
#    1838                   output_keys=output_keys,
# -> 1839                   name=name)
#    1840         with theano.change_flags(compute_test_value="off"):
#    1841             fn = m.create(defaults)
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\compile\function_module.py in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys, name)
#    1517                         optimizer, inputs, outputs)
#    1518                 else:
# -> 1519                     optimizer_profile = optimizer(fgraph)
#    1520
#    1521                 end_optimizer = time.time()
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in __call__(self, fgraph)
#      97
#      98         """
# ---> 99         return self.optimize(fgraph)
#     100
#     101     def add_requirements(self, fgraph):
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in optimize(self, fgraph, *args, **kwargs)
#      86             orig = theano.tensor.basic.constant.enable
#      87             theano.tensor.basic.constant.enable = False
# ---> 88             ret = self.apply(fgraph, *args, **kwargs)
#      89         finally:
#      90             theano.tensor.basic.constant.enable = orig
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in apply(self, fgraph)
#     240                     nb_nodes_before = len(fgraph.apply_nodes)
#     241                     t0 = time.time()
# --> 242                     sub_prof = optimizer.optimize(fgraph)
#     243                     l.append(float(time.time() - t0))
#     244                     sub_profs.append(sub_prof)
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in optimize(self, fgraph, *args, **kwargs)
#      86             orig = theano.tensor.basic.constant.enable
#      87             theano.tensor.basic.constant.enable = False
# ---> 88             ret = self.apply(fgraph, *args, **kwargs)
#      89         finally:
#      90             theano.tensor.basic.constant.enable = orig
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in apply(self, fgraph, start_from)
#    2126                     continue
#    2127                 current_node = node
# -> 2128                 nb += self.process_node(fgraph, node)
#    2129             loop_t = time.time() - t0
#    2130         finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in process_node(self, fgraph, node, lopt)
#    2022                 self.failure_callback(e, self,
#    2023                                       [(x, None) for x in node.outputs],
# -> 2024                                       lopt, node)
#    2025                 return False
#    2026             else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in warn_inplace(exc, nav, repl_pairs, local_opt, node)
#    1916         if isinstance(exc, InconsistencyError):
#    1917             return
# -> 1918         return NavigatorOptimizer.warn(exc, nav, repl_pairs, local_opt, node)
#    1919
#    1920     @staticmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in warn(exc, nav, repl_pairs, local_opt, node)
#    1902             # We always crash on AssertionError because something may be
#    1903             # seriously wrong if such an exception is raised.
# -> 1904             raise exc
#    1905
#    1906     @staticmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\gof\opt.py in process_node(self, fgraph, node, lopt)
#    2017         lopt = lopt or self.local_opt
#    2018         try:
# -> 2019             replacements = lopt.transform(node)
#    2020         except Exception as e:
#    2021             if self.failure_callback is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\theano\tensor\nnet\opt.py in local_abstractconv_check(node)
#     498             'do you have a BLAS library installed Theano can link against? '
#     499             'On the CPU we do not support float16.' %
# --> 500             node.op.__class__.__name__)
#     501
#     502 optdb.register('AbstractConvCheck',
#
# AssertionError: AbstractConv2d Theano optimization failed: there is no implementation available supporting the requested options. Did you exclude both "conv_dnn" and "conv_gemm" from the optimizer? If on GPU, is cuDNN available and does the GPU support it? If on CPU, do you have a BLAS library installed Theano can link against? On the CPU we do not support float16.
